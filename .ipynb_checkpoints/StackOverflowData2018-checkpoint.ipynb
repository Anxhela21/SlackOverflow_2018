# %% [markdown]
# # Slack Overflow 2018 Survey Data #
# CRISP-RM Flow:
#
# Understanding the business. Firstly an in-depth analysis of the business objectives and needs has to be done. ...
# Understanding the data. Initial facts and figures collection are done from all available sources. ...
# Preparation of data. ...
# Modelling. ...
# Evaluation. ...
# Setting out.
#
#
# # 1. Understanding Business Objective: #
# The goal of this analysis will be to find out more about the top tools to see how they compare with the outcome of 2019's survey results. Specifically, we'll focus on the following attributes; Top Languages, Frameworks, IDE and Developer roles for 2018 and how those compared to the 2019 survey (based on just results from Slack Overflow).
#
#
#
# # 2.  Understanding the Data: #
# The data presents 98855 developer survey participant's results with 129 attributes. These range from demographics to lifestyle to skillset to top tools used in 2018.

# %% [markdown]
# # 3. Preparation of Data: #

# %%
# %load_ext nb_black

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("Copy of survey_results_public.csv")
# Out:
# C:\Users\AnxhelaCoba\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3044: DtypeWarning: Columns (8,12,13,14,15,16,50,51,52,53,55,56,57,58,59,60,61,62,63,64,65,66,67,68,69,70,71,72,73,74,75,76,77,78,79,80,81,82,83,84,85,93,94,95,96,97,98,99,100,101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120,121,122,123,124,125,126,127,128) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def split_column_value(df, column_name, separator=';'):
    '''
    INPUT - ori_df  - pandas dataframe -  original dataframe
            column_name - string - the name of the column you would like to splite the value
            separator - string - The is a delimiter. The string splits at this specified separator. If is not provided then ; is the separator.
    OUTPUT - 
            df - pandas dataframe - all value for the column of original dataframe
    '''
    df = pd.DataFrame(df[column_name].dropna().str.split(separator).tolist()).stack()
    return df

# %%
split_column_value(df, 'IDE')
# Out:
# 0      0                 Komodo
#        1                    Vim
#        2     Visual Studio Code
# 1      0      IPython / Jupyter
#        1           Sublime Text
#        2                    Vim
# 2      0          Visual Studio
#        1     Visual Studio Code
# 3      0              Notepad++
#        1          Visual Studio
#        2     Visual Studio Code
# 4      0               IntelliJ
#        1                PyCharm
#        2     Visual Studio Code
# 5      0                   Atom
#        1     Visual Studio Code
# 6      0                   Atom
#        1              Notepad++
#        2           Sublime Text
#        3     Visual Studio Code
# 7      0               IntelliJ
#        1                PyCharm
#        2           Sublime Text
#        3                    Vim
# 8      0                Eclipse
#        1               NetBeans
# 9      0              Notepad++
#        1          Visual Studio
# 10     0          Visual Studio
# ...

# %%
split_column_value(df, 'LanguageWorkedWith').value_counts()
# Out:
# JavaScript              54686
# HTML                    53628
# CSS                     50979
# SQL                     44670
# Java                    35521
# Bash/Shell              31172
# Python                  30359
# C#                      26954
# PHP                     24071
# C++                     19872
# C                       18042
# TypeScript              13626
# Ruby                     7911
# Swift                    6310
# Assembly                 5760
# Go                       5532
# Objective-C              5510
# VB.NET                   5254
# R                        4813
# Matlab                   4564
# VBA                      3810
# Kotlin                   3508
# Scala                    3420
# Groovy                   3373
# Perl                     3280
# Visual Basic 6           3087
# Lua                      2733
# CoffeeScript             2603
# Delphi/Object Pascal     2025
# Haskell                  1961
# Rust                     1857
# ...

# %%
df['IDE']= df['IDE'].str.split(";")

# %%
df_new["IDE"].unique()
# Out:
# array(['Komodo', 'IPython / Jupyter', 'Visual Studio', ...,
#        'Somewhat difficult', 'Very difficult',
#        'Neither easy nor difficult'], dtype=object)

# %%
def get_top_ten(df, column):
    """
    INPUT:
    Takes in a pandas dataframe and a column
    
    OUTPUT:
    returns a list of the top ten highest value counts for specified column
    """
    return df[column].value_counts().sort_values(ascending=False)[:10]

# %%
get_top_ten(df_new, "IDE")
# Out:
# Yes    392757
# 1.0    260770
# 4.0    260770
# 5.0    260770
# 2.0    260768
# 3.0    260768
# No     258412
# 6.0    216527
# 7.0    216527
# 8.0    117227
# Name: IDE, dtype: int64

# %%
df["FrameworkWorkedWith"].value_counts().sort_values(ascending=False)[:10]
# Out:
# .NET Core                4517
# Node.js                  4453
# Node.js;React            3436
# Spring                   2830
# Angular;Node.js          2594
# Angular                  2561
# Django                   1931
# React                    1712
# Angular;Node.js;React    1613
# Angular;.NET Core        1297
# Name: FrameworkWorkedWith, dtype: int64

# %%
df["FrameworkDesireNextYear"].value_counts().sort_values(ascending=False)[:10]
# Out:
# Node.js;React            3797
# .NET Core                2924
# Node.js                  2797
# React                    2249
# TensorFlow               2204
# Angular;Node.js;React    1833
# Angular;Node.js          1438
# Spring                   1372
# Django                   1189
# Angular                  1132
# Name: FrameworkDesireNextYear, dtype: int64

# %%
df["ConvertedSalary"].describe()
# Out:
# count    4.770200e+04
# mean     9.578086e+04
# std      2.023482e+05
# min      0.000000e+00
# 25%      2.384400e+04
# 50%      5.507500e+04
# 75%      9.300000e+04
# max      2.000000e+06
# Name: ConvertedSalary, dtype: float64

# %%
def n(n):
    for i in range(n):
        print(i)

# %%
df.shape
# Out:
# (11390, 129)

# %%
#thresh = len(df) * 0.5
#df.dropna(thresh=thresh, axis=1, inplace=True)

# %%
# df["FrameworkWorkedWith"].value_counts().sort_values(ascending=False)[:10]


def make_graph(df, column):

    plt.figure(figsize=[15, 10])
    plt.ylabel(column.title(), fontsize=20, weight="bold")
    plt.xlabel("Number of Participants".title(), fontsize=20, weight="bold")
    plt.xticks(fontsize=20)
    plt.yticks(fontsize=20, rotation=90)
    df[column].value_counts().sort_values(ascending=False)[:10].plot(kind="barh")
    plt.style.use("ggplot")

# %%
make_graph(df, "FrameworkWorkedWith")
plt.ylabel("Top Frameworks".title(), fontsize=20, weight="bold")
# Out:
# Text(0, 0.5, 'Top Frameworks')

# %%
make_graph(df, "DevType")
plt.ylabel("Top Developer Roles".title(), fontsize=20, weight="bold")
# Out:
# Text(0, 0.5, 'Top Developer Roles')

# %%
make_graph(df, "IDE")

# %%
make_graph(df, "LanguageWorkedWith")

# %%
make_graph(df, "LanguageDesireNextYear")

# %%
df.dropna(axis=0, how="any", inplace=True)

# %%
df.shape

# %%
sb.heatmap(df.corr())

# %%
df_new = df.loc[:, ~df.columns.str.startswith(("Assess", "Hyp", "Ads"))]

# %%
df_new.columns

# %%
df_cat = df_new.select_dtypes(include=["object"]).columns


for cat in df_cat:
    df_new = pd.concat(
        [
            df_new.drop(cat, axis=1),
            pd.get_dummies(df_new[cat], prefix=cat, prefix_sep="_", drop_first=True),
        ],
        axis=1,
    )

# %%
df_new.head()

# %%
# fig = plt.figure(figsize=(15, 20))
# ax = fig.gca()
df_new["Hobby_Yes"].hist()
# (ax=ax)
